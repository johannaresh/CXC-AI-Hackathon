# %% [markdown]
# # EdgeAudit — Exploration Notebook
#
# Use this notebook for prototyping feature engineering, model training, and data analysis.

# %%
import numpy as np
import pandas as pd

# Load synthetic data
import json
with open('../data/synthetic/synthetic_strategies.json') as f:
    strategies = json.load(f)

print(f'Loaded {len(strategies)} strategies')
